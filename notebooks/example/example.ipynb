# %%
# %run ../includes/common-20230414.ipynb
# Out:
# CPython 2024-06-13T13:46:13.102778
# <style>.container { width:100% !important; }</style>
# CPU times: user 1.59 ms, sys: 0 ns, total: 1.59 ms
# Wall time: 1.45 ms

# %%
resultfiles = {
    # 'Baleen AD-ML PF-ML-Partial': 'runs/example/baleen/prefetch_ml-on-partial-hit/ml-ap-0.798545_6_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma',
    # 'Baleen OPT (Oracle)': 'runs/example/baleen/prefetch_opt/offline-ap-25.9144_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma',
    # "CoinFlip": "/home/cc/runs/exp_reproduce_spring23/20230412_19traces_1p/201910_Region1_0_1_366.475GB_WR35.599MBS/ap_coinflip/policy_hits/prefetch_never_episode/i_2_ea_7182.69/coinflip-ap-0.077218_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "RejectX": "/home/cc/runs/exp_reproduce_spring23/20230412_19traces_1p/201910_Region1_0_1_366.475GB_WR35.599MBS/ap_rejectx/policy_hits/prefetch_never_episode/i_2_ea_6529.05/rejectx-ap-1_0.580327_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "Baleen (No Prefetch)": "/home/cc/runs/exp_reproduce_spring23/20230412_19traces_1p/201910_Region1_0_1_366.475GB_WR35.599MBS/ap_mlnew/policy_servicetimesize/prefetch_never_episode/i_2_ea_6119.97/ml-ap-0.686769_6_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "Baleen": "/home/cc/runs/exp_reproduce_spring23/20230412_19traces_1p/201910_Region1_0_1_366.475GB_WR35.599MBS/ap_mlnew/policy_servicetimesize/prefetch_predict_acctime-episode-predict/i_2_ea_6592.99/ml-ap-0.830268_6_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT (Full)": "/home/cc/Baleen-FAST24/runs/exp_reproduce_spring23/20230403_19traces/201910_Region1_0_0.1_366.475GB_WR35.599MBS/ap_opt/policy_servicetimesize/prefetch_at_start_acctime-episode/i_2_ea_4752.89/offline-ap-25.9144_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT (Per Day)": "/home/cc/Baleen-FAST24/runs/exp_reproduce_spring23/20230403_19traces/201910_Region1_0_0.1_366.475GB_WR35.599MBS/ap_opt/policy_servicetimesize/opt-per-day/i_2_ea_4752.89/offline-ap-25.9144_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma"
    # "OPT/Day - 5": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/5/offline-ap-5_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT/Day - 15": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/15/offline-ap-15_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT/Day - 25": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/25/offline-ap-25_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT/Day - 35": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/35/offline-ap-35_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT/Day - 50": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/50/offline-ap-50_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    # "OPT/Day - 60": "/home/cc/Baleen-FAST24/runs/ap_opt_per_day/threshold/60/offline-ap-60_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma"
    "OPT/Full - 5": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/5/offline-ap-5_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    "OPT/Full - 15": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/15/offline-ap-15_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    "OPT/Full - 25": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/25/offline-ap-25_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    "OPT/Full - 35": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/35/offline-ap-35_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    "OPT/Full - 45": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/45/offline-ap-45_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma",
    "OPT/Full - 60": "/home/cc/Baleen-FAST24/runs/ap_opt_full/threshold/60/offline-ap-60_lru_366.475GB/full_0_0.1_cache_perf.txt.lzma"
}

# %%
res = {}
for label, filename in resultfiles.items():
    res[label] = results.get({'Region': 'Region1', 'Filename':f'{filename}'})
# Out:
# HAVE FILENAME
# Error: 'Prefetch-Range'
# <class 'pandas.core.frame.DataFrame'>
# Index(['Write Rate (MB/s)', 'IOPS Saved Ratio', 'Service Time Saved Ratio', 'Hit Rate (Hz)', 'AP Threshold', 'AP Probability', 'Cache Size (GB)', 'Wasted', 'Evictions', 'Filename',
#        ...
#        'WarmupTime', 'Prefetch Ratio', 'Completed', 'Region', 'ExperimentSuffix', 'ConfigFile', 'Target Cache Size', 'RegionLabel', 'RegionLabelOrig', 'AdmissionPolicyLabel'], dtype='object', length=461)
# HAVE FILENAME
# Error: 'Prefetch-Range'
# <class 'pandas.core.frame.DataFrame'>
# Index(['Write Rate (MB/s)', 'IOPS Saved Ratio', 'Service Time Saved Ratio', 'Hit Rate (Hz)', 'AP Threshold', 'AP Probability', 'Cache Size (GB)', 'Wasted', 'Evictions', 'Filename',
#        ...
#        'WarmupTime', 'Prefetch Ratio', 'Completed', 'Region', 'ExperimentSuffix', 'ConfigFile', 'Target Cache Size', 'RegionLabel', 'RegionLabelOrig', 'AdmissionPolicyLabel'], dtype='object', length=461)
# HAVE FILENAME
# ...

# %%
ax = plt.gca()
for label, resv in res.items():
    d_ = res[label].progress['GET'][60]
    # print(res[label].pstats["GET"])
    d_['Days'] = d_['Elapsed Trace Time'] / 3600 / 24
    d_.plot(x='Days', y='Util', ax=ax, label=label)
    # Make figure wider
    fig = plt.gcf()
    fig.set_size_inches(40, 5)
    # print max of util
    print(f"{label}: {d_['Util'].max()}")
    # Max y limit 40
    plt.ylim(0, 30)
    # set title
    plt.title('GET Utilization (%)')
plt.show()
ax = plt.gca()
for label, resv in res.items():
    d_ = res[label].progress['GET'][60]
    # print(res[label].pstats["GET"])
    d_['Days'] = d_['Elapsed Trace Time'] / 3600 / 24
    d_.plot(x='Days', y='Flash Writes', ax=ax, label=label)
    # Make figure wider
    fig = plt.gcf()
    fig.set_size_inches(40, 5)
    # print max of util
    print(f"{label}: {d_['Flash Writes'].max()}")
    # set title
    plt.title('Flash Writes')
plt.show()

ax = plt.gca()
for label, resv in res.items():
    d_ = res[label].progress['GET'][60]
    # print(res[label].pstats["GET"])
    d_['Days'] = d_['Elapsed Trace Time'] / 3600 / 24
    d_['Diff Flash Writes'] = d_['Flash Writes'].diff()
    d_.plot(x='Days', y='Diff Flash Writes', ax=ax, label=label)
    # Make figure wider
    fig = plt.gcf()
    fig.set_size_inches(40, 5)
    # print max of util
    print(f"{label}: {d_['Diff Flash Writes'].max()}")
    # set title
    plt.title('Diff Flash Writes')
plt.show()
    
# res['Baleen (ML-Range on Partial-Hit)'].progress['GET+PUT'][600].plot(x='Elapsed Trace Time', y='Util', ax=ax)
# Out:
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 5: 32.41101489888049
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 15: 22.846872346444037
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 25: 21.813747902028364
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 35: 21.41072267458336
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 45: 21.759218521687533
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# GENERATE PROG
# OPT/Full - 60: 22.01009185721727
# OPT/Full - 5: 2777560901.107426
# OPT/Full - 15: 10111039301.107426
# OPT/Full - 25: 29008557446.12891
# OPT/Full - 35: 49585681798.128914
# OPT/Full - 45: 66942367110.128914
# OPT/Full - 60: 90781618318.47758
# OPT/Full - 5: 10055809.697414398
# OPT/Full - 15: 10252212.230566978
# ...

# %%
print(list(df.columns))
wanted_name = []
for name in df.columns:
    if 'write' in name.lower():
        wanted_name.append(name)
        
print(wanted_name)
# Out:
# ['Write Rate (MB/s)', 'IOPS Saved Ratio', 'Service Time Saved Ratio', 'Hit Rate (Hz)', 'AP Threshold', 'AP Probability', 'Cache Size (GB)', 'Wasted', 'Evictions', 'Filename', 'Avg Eviction Age (Logical)', 'Avg Eviction Age (s)', 'Max Max Interarrival Time (Logical)', 'Max Max Interarrival Time (s)', 'Avg Max Interarrival Time (Logical)', 'Avg Max Interarrival Time (s)', 'AdmissionPolicy', 'AdmitBufferSize', 'SamplingRatio', 'SampleRatio', 'SampleStart', 'Total IOPS', 'PrefetchWhenThreshold', 'ApOpt', 'SimApOpt', 'SimJobId', 'LogInterval', 'NumCacheElems', 'ServiceTimeTotalOrig', 'TotalIOPSSaved', 'TotalIOPSSavedOnly', 'TotalIOPSPartialHits', 'IOPSSavedRatio', 'IOPSSavedOnlyRatio', 'IOPSPartialHitsRatio', 'TotalChunkHits', 'TotalChunkSaved', 'ChunkHitRatio', 'TotalIOPSSavedAdmitBuffer', 'TotalIOPSSavedAdmitBufferOnly', 'TotalIOPSPartialHitsAdmitBuffer', 'IOPSSavedAdmitBufferRatio', 'IOPSSavedAdmitBufferOnlyRatio', 'IOPSPartialHitsAdmitBufferRatio', 'TotalChunkHitsAdmitBuffer', 'TotalC
# ...

# %%
rows = []
for label, resv in res.items():
    resv.summary['Label'] = label
    rows.append(resv.summary)
df = pd.concat(rows)
print(df[['Label', 'P50ServiceTimeUtil1']])
(df[['Label', 'P50ServiceTimeUtil1']].set_index('Label')['P50ServiceTimeUtil1']).plot.bar()
# Make figure tall so eveyrthing fit
fig = plt.gcf()
fig.set_size_inches(5, 10)
plt.ylabel("Median Backend Load\n(% of no cache)")
plt.xlabel("")
plt.show()
fig = plt.gcf()
fig.set_size_inches(5, 10)
print(df[['Label','PeakServiceTimeUtil2']].set_index('Label')['PeakServiceTimeUtil2'])
(df[['Label','PeakServiceTimeUtil1']].set_index('Label')['PeakServiceTimeUtil1'] * 1) .plot.bar()
plt.ylabel("Peak Backend Load\n(% of no cache)")
plt.xlabel("")
plt.show()
fig = plt.gcf()
fig.set_size_inches(5, 10)
(df[['Label', 'TotalEpisodesAdmitted']].set_index('Label')['TotalEpisodesAdmitted']) .plot.bar()
plt.ylabel("Total Eps Admitted")
plt.xlabel("")
plt.show()
fig = plt.gcf()
fig.set_size_inches(5, 10)
(df[['Label', 'Write Rate (MB/s)']].set_index('Label')['Write Rate (MB/s)']) .plot.bar()
plt.ylabel("Write Rate (MB/s)")
plt.xlabel("")
plt.show()
pass
# Out:
#            Label  P50ServiceTimeUtil1
# 0   OPT/Full - 5            13.880512
# 0  OPT/Full - 15            12.312824
# 0  OPT/Full - 25            11.972052
# 0  OPT/Full - 35            11.863434
# 0  OPT/Full - 45            11.812144
# 0  OPT/Full - 60            11.804625
# Label
# OPT/Full - 5     32.408492
# OPT/Full - 15    22.723809
# OPT/Full - 25    21.864268
# OPT/Full - 35    21.514747
# OPT/Full - 45    21.868719
# OPT/Full - 60    21.911681
# Name: PeakServiceTimeUtil2, dtype: float64

# %%
df_ = (df[['Label', 'PeakServiceTimeUsedRatio1']].set_index('Label'))['PeakServiceTimeUsedRatio1']
print("Savings in Peak Load from Baleen on Region1, Sample 0")
print(df_)
print((1 - (df_.loc['Baleen AD-ML PF-ML-Partial'] / df_.loc['Baleen OPT (Oracle)']))*100)
# Out:
# Savings in Peak Load from Baleen on Region1, Sample 0
# Label
# Baleen AD-ML PF-ML-Partial    0.186822
# Baleen OPT (Oracle)           0.198487
# Name: PeakServiceTimeUsedRatio1, dtype: float64
# 5.8771646757415645
